# %%
print(2+3)
# Out:
# 5

# %%
def add(x,y):
    return(x+y)
add(2,4)
# Out:
# 6

# %%
def greet(name="guest"):
    print(f"Hello{name}!")
greet()
greet("preet")
# Out:
# Helloguest!
# Hellopreet!

# %%
age=int(input("age:"))
if age>18:
    print("eligible to vote")
else:
    print("not valid")
# Out:
# age: 12
# not valid

# %%
score=int(input("Score:"))
if score>90:
    print("A grade")
elif score>80:
    print("B grade")
else:
    print("c grade")
# Out:
# Score: 34
# c grade

# %%
def add(a,b):
    return a+b
def multiply(a,b):
    return a*b
def division(a,b):
    return a/b
def subract(a,b):
    return a-b
print (add(2,3))
print (add(2.3,0))
print (multiply(12.3,4))
# Out:
# 5
# 2.3
# 49.2

# %%
def display_profile(**kwargs):
    for k, value in kwargs.items():
        print(f"{k}: {value}")

display_profile(name="Alice", role="Engineer")
# Out:
# name: Alice
# role: Engineer

# %%
def complete_profile(*args, **kwargs):
    print("Positional:", args)
    print("Keyword:", kwargs)

complete_profile("Python", level="Advanced", year=2025)
# Out:
# Positional: ('Python',)
# Keyword: {'level': 'Advanced', 'year': 2025}

# %%
def factorial(x):
    if x == 0:
        return 1
    return x * factorial(x - 1)

print(factorial(12))
# Out:
# 479001600

# %%
sq = lambda x: x ** 2
print(sq(97))  # Output: 25
# Out:
# 9409

# %%
def disp(name,age,department):
    print(f"name:{name},age:{age},department:{department}")
disp(name="raksh",department="cse",age=19)
# Out:
# name:raksh,age:19,department:cse

# %%
def login(username, password):
    print(f"User: {username}")

login("admin", "1234")
# Out:
# User: admin

# %%
def user(**details):
    for key, value in details.items():
        print(f"{key}: {value}")

user(name="raksh", role="Developer", level="junior")
user(name="raksh", role="Developer", level="junior")
# Out:
# name: raksh
# role: Developer
# level: junior
# name: raksh
# role: Developer
# level: junior

# %%
def full_profile(name, *skills, **info):
    print("Name:", name)
    print("Skills:", skills)
    print("Details:", info)

full_profile("Alice", "Python", "ML", age=30, city="Toronto")
# Out:
# Name: Alice
# Skills: ('Python', 'ML')
# Details: {'age': 30, 'city': 'Toronto'}

# %%
def configure(mode="light"):
    print(f"Mode: {mode}")

configure(mode="dark")
# Out:
# Mode: dark

# %%
def add(a,b,c):
    return a+b+c
values={"a":2,"b":12,"c":43}
print(add(**values))
# Out:
# 57

# %%
count = 10

def increment():
    global count
    count += 1

increment()
print(count)  # Output: 1
# Out:
# 11

# %%
val=12
def local():
    val=10
    return 
print(local())
print(val)
# Out:
# 10
# 12

# %%
def outer():
    message = "Hello"
    def inner():
        print(message)  
    inner()
outer()

# %%
def outer():
    count = 0
    def inner():
        nonlocal count
        count += 9
        print(count)
    inner()
outer()
# Out:
# 9

# %%
x = "Global"

def outer():
    x = "Enclosing"

    def inner():
        nonlocal x 
        x= "Local"
        print(x)

    inner()

outer()
# Out:
# Local

# %%
for i in range(9):
    a = i

print(a)  # Accessible outside loop
# Out:
# 8

# %%
x = "Global"

def outer():
    x = "Enclosing"

    def inner():
        x = "Local"
        print(x)
    inner()
    print(x)
outer()
print(x)
# Out:
# Local
# Enclosing
# Global

# %%
value = 5

def update():
   value+= 1
   print(value)

# %%
x = 100

def outer():
    def inner():
        global x
        x = 200
    inner()
    print(x)

outer()
print(x)
# Out:
# 200
# 200

# %%
x =3

def outer():
    x = 1
    
    def inner():
        global x
        x = 2

    inner()
    print("Outer x:", x)

outer()
print("Global x:", x)
# Out:
# Outer x: 1
# Global x: 2

# %%
value = 5

def update():
    value = value + 1  
print(value)
# Out:
# 5

# %%
def print_numbers(n):
    if n == 0:
        return
    print_numbers(n - 1)
    print(n)
    
print_numbers(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def fact(n):
    if n==0 and n>=0:
        return 1
    else:
        return n*fact(n-1)
print(fact(12))
# Out:
# 479001600

# %%
def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n - 1) + fibonacci(n - 2)

print(fibonacci(6))  # Output: 8
# Out:
# 8

# %%
def infinite_recursion():
    return infinite_recursion()
print(infinite_recursion)
# Out:
# <function infinite_recursion at 0x0000021C9C66BEC0>

# %%
def rev(text):
    if len(text)==0:
        return text
    return rev(text[1:])+text[0]
print(rev("pope"))
# Out:
# epop

# %%
import sys

print(sys.getrecursionlimit())  # Default ~1000
# Out:
# 3000

# %%
from functools import lru_cache

@lru_cache(maxsize=None)
def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n - 1) + fibonacci(n - 2)

print(fibonacci(30))
# Out:
# 832040

# %%
import math

help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
import datetime

today = datetime.date.today()
print(today)
# Out:
# 2026-07-10

# %%
import datetime

today = datetime.date.today()
print(today)
# Out:
# 2026-07-10

# %%
def main():
    print("Main function executed")

if __name__ == "__main__":
    main()
# Out:
# Main function executed

# %%
import math as o

print(o.pi)     # Output: 3.141592653589793
# Out:
# 3.141592653589793

# %%
import math as r

print(r.sqrt(256))
# Out:
# 16.0

# %%
import sys
print(sys.path)
# Out:
# ['C:\\Users\\raksh_hp2y5k\\miniconda3\\envs\\test12\\python311.zip', 'C:\\Users\\raksh_hp2y5k\\miniconda3\\envs\\test12\\DLLs', 'C:\\Users\\raksh_hp2y5k\\miniconda3\\envs\\test12\\Lib', 'C:\\Users\\raksh_hp2y5k\\miniconda3\\envs\\test12', '', 'C:\\Users\\raksh_hp2y5k\\miniconda3\\envs\\test12\\Lib\\site-packages']

# %%
# my_package/module1.py
def greet():
    return "Hello from module1"

# %%
from setuptools import setup, find_packages

# %%
def main():
    print("Main function executed")

if __name__ == "__main__":
    main()
print(__name__)
# Out:
# Main function executed
# __main__

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\raksh_hp2y5k\kact\pynotes\notebooks\basics

# %%
import os

os.mkdir("new_folder")
os.makedirs("parent/child/grandchild")

# %%
import os

items = os.listdir(".")
print(items)
# Out:
# ['.ipynb_checkpoints', 'age-calculator.ipynb', 'basics.ipynb', 'package']

# %%
import os

print(os.path.exists("age-calculator.ipynb"))      # True or False
print(os.path.isfile("age-calculator.ipynb"))     # Checks file
print(os.path.isdir("c:/"))    # Checks directory
# Out:
# True
# True
# True

# %%
with open("sample.txt", "w") as file:
    file.write("Hello!")
with open("sample.txt", "r") as file:
    content = file.read()

print(content)
# Out:
# Hello!

# %%
import os

os.rename("sample.txt", "renamed.txt")

# %%
import os

print(os.listdir("."))
# Out:
# ['.ipynb_checkpoints', 'age-calculator.ipynb', 'basics.ipynb', 'package']

# %%
import shutil

shutil.copy("age-calculator.ipynb", "backup.ipynb")
# Out:
# 'backup.ipynb'

# %%
with open("backup.ipynb","r") as f:

 print(f.read())
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 1,
#    "id": "d3a0ad6e-d750-4693-a72e-8dbc9cd4155f",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "from datetime import datetime"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "id": "cf260179-e8a8-4f19-87cd-f21a9c6d43a2",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "def get_age(d):\n",
#     "    d1 = datetime.now()\n",
#     "    months = (d1.year - d.year) * 12 + d1.month - d.month\n",
#     "\n",
#     "    year = int(months / 12)\n",
#     "    return year"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "id": "db2aca8b-2573-4ba4-8521-63fe8ff1ffc4",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "age = get_age(datetime(1991, 1, 1))"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 4,
#    "id": "8f080b7f-74e7-4a0e-8034-b332499e7c1b",
#    "metadata": {},
# ...

# %%
from pathlib import Path

file_path = Path("renamed.txt")

file_path.write_text("Using pathlib module")
print(file_path.read_text())

print(file_path.exists())
print(file_path.parent)
# Out:
# Using pathlib module
# True
# .

# %%
import csv
with open("True.csv","w",newline="") as file:
    writer=csv.writer(file)
    writer.writerow(["Name","age","dept"])
    writer.writerow(["raksh","19","cse"])
    writer.writerow(["bob","19","cse"])

# %%
import csv
with open("True.csv","r")as f:
    reader=csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Name', 'age', 'dept']
# ['raksh', '19', 'cse']
# ['bob', '19', 'cse']

# %%
import csv
with open("True.csv","r")as f:
    reader=csv.DictReader(f)
    for row in reader:
        print(row['Name'],row["age"])
# Out:
# raksh 19
# bob 19

# %%
import csv
data=[["john",25,"toronto"],
["josh",25,"berlin"]]
with open("people.csv","w") as f:
    r=csv.writer(f)  
    r.writerows(data)
with open("people.csv","r") as f:
    reader=csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['john', '25', 'toronto']
# []
# ['josh', '25', 'berlin']
# []

# %%
import csv
fieldnames =["name","age","city"]
with open("users.csv","w",newline="") as f:
    writer=csv.DictWriter(f,fieldnames=fieldnames)
    writer.writeheader()
    writer.writerow({"name": "Alice", "age": 25, "city": "Paris"})
    writer.writerow({"name": "Bob", "age": 30, "city": "Rome"})
with open("users.csv","r") as f:
    reader=csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['name', 'age', 'city']
# ['Alice', '25', 'Paris']
# ['Bob', '30', 'Rome']

# %%
import csv
fieldnames =["name","age","city"]
with open("users.csv","w",newline="") as f:
    writer=csv.DictWriter(f,fieldnames=fieldnames)
    writer.writeheader()
    writer.writerow({"name": "Alice", "age": 25, "city": "Paris"})
    writer.writerow({"name": "Bob", "age": 30, "city": "Rome"})
with open("users.csv","r") as f:
    reader=csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['name', 'age', 'city']
# ['Alice', '25', 'Paris']
# ['Bob', '30', 'Rome']
