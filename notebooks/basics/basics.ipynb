# %%
print("hello")
# Out:
# hello

# %%
print(2+3)
# Out:
# 5

# %%
def add(x,y):
    return(x+y)
add(2,4)
# Out:
# 6

# %%
def greet(name="guest"):
    print(f"Hello{name}!")
greet()
greet("preet")
# Out:
# Helloguest!
# Hellopreet!

# %%
age=int(input("age:"))
if age>18:
    print("eligible to vote")
else:
    print("not valid")
# Out:
# age: 12
# not valid

# %%
score=int(input("Score:"))
if score>90:
    print("A grade")
elif score>80:
    print("B grade")
else:
    print("c grade")
# Out:
# Score: 34
# c grade
